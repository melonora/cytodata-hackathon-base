# %%
from upath import UPath as Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nbvv

from serotiny.io.image import image_loader
from cytodata_aics.io_utils import rescale_image
# Out:
# 20-Oct-22 16:28:28 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).

# %%
df = pd.read_parquet("s3://allencell-hipsc-cytodata/hackathon_manifest_17oct2022.parquet")
print(f'Number of cells: {len(df)}')
print(f'Number of columns: {len(df.columns)}')
# Out:
# Number of cells: 214037
# Number of columns: 77

# %%
#From Chapter 5
#loading library, making path for 
from serotiny.transforms.dataframe.transforms import split_dataframe
Path("/home/aicsuser/serotiny_data/").mkdir(parents=True, exist_ok=True)

# Sample n cells per group
n = 2000 # number of cells per mitotic class
cells_to_include=[]
for name, group in df.groupby('cell_stage'):    
    sampled_group = group.sample(min([n,len(group)]))
    cells_to_include.append(sampled_group)
df_mitocells = pd.concat(cells_to_include).reset_index(drop=True)

# Discarding all the M6M7_single cells
df_mitocells = df_mitocells.drop(df_mitocells[df_mitocells['cell_stage']=='M6M7_single'].index)

df_mitocells['cell_stage_encoded'] = pd.factorize(df_mitocells['cell_stage'])[0]

# Add the train, test and validate split
df_mitocells = split_dataframe(dataframe=df_mitocells, train_frac=0.7, val_frac=0.2, return_splits=False)

df_mitocells.to_csv("/home/aicsuser/serotiny_data/keith_mitocells.csv") 
print(f"Number of cells: {len(df_mitocells)}")
print(f"Number of columns: {len(df_mitocells.columns)}")
# Out:
# Number of cells: 8179
# Number of columns: 79

# %%
class_count = df_mitocells["cell_stage"].unique()
print(class_count)
# Out:
# ['M0' 'M1M2' 'M3' 'M4M5' 'M6M7_complete']

# %%
stages = df_mitocells[['cell_stage', 'cell_stage_encoded']].head()
print(stages)
# Out:
#   cell_stage  cell_stage_encoded
# 0         M0                   0
# 1         M0                   0
# 2         M0                   0
# 3         M0                   0
# 4         M0                   0

# %%
# The bar plot again
# %matplotlib inline
plt.style.use('seaborn-v0_8-white')   #print(plt.style.available)
# Code from Chapter 4 to make a bar plot
table = pd.pivot_table(df_mitocells, index="cell_stage", aggfunc="size")
fig, axes = plt.subplots(figsize=(20, 7), dpi=100)
table.plot.barh(stacked=True, ax=axes)
axes.set_ylabel(None)
axes.set_title("Structures and Cell Stage")
axes.grid(True, which="major", axis="x")
axes.set_axisbelow(True)
axes.invert_yaxis()
plt.show()
print(table)
# Out:
# cell_stage
# M0               2000
# M1M2             2000
# M3                981
# M4M5             2000
# M6M7_complete    1198
# dtype: int64

# %%
# we need the commands we type to be ran from the serotiny project root
# (because that's what `serotiny` expects) so we change directories here,
# so we can run commands within the notebook
import os
os.chdir("/home/aicsuser/eyeballExpress/cytodata-hackathon-base")

# %%
from datetime import datetime

# util to avoid referring to the same run unintentionally
now_str = lambda : datetime.now().strftime("%Y%m%d_%H%M%S")

# %%
run_name = f"keith_bf_noDropout_{now_str()}"
print(run_name)

# !serotiny train \
    model=brightfield_classifier_3d_noDropOut \
    data=brightfield_dataloader_3d \
    mlflow.experiment_name=eyeballExpress \
    mlflow.run_name={run_name} \
    trainer.gpus=[0] \
    trainer.max_epochs=8
# Out:
# keith_bf_noDropout_20221020_062002
# [2022-10-20 06:20:06,935][pytorch_lightning.utilities.seed][INFO] - Global seed set to 42
# [2022-10-20 06:20:06,936][serotiny.ml_ops.ml_ops][INFO] - Instantiating datamodule
# [2022-10-20 06:20:09,903][serotiny.ml_ops.ml_ops][INFO] - Instantiating trainer
# [2022-10-20 06:20:09,939][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True, used: True
# [2022-10-20 06:20:09,939][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2022-10-20 06:20:09,939][pytorch_lightning.utilities.rank_zero][INFO] - IPU available: False, using: 0 IPUs
# [2022-10-20 06:20:09,939][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2022-10-20 06:20:09,940][serotiny.ml_ops.ml_ops][INFO] - Instantiating model
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# [2022-10-20 06:20:09,995][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmph44i2r1k
# [2022-10-20 06:20:09,995][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmph44i2r1k/_remote_module_non_scriptable.py
# [2022-10-20 06:20:10,012][serotiny.ml_ops.mlflow_utils][INFO] - Validating and processing MLFlow configuration
# /opt/conda/lib/python3.10/site-packages/serotiny/ml_ops/mlflow_utils.py:156: FutureWarning: ``mlflow.tracking.fluent.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   for run_info in mlflow.list_run_infos(experiment_id=experiment_id):
# /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1599: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   return MlflowClient().list_run_infos(
# [2022-10-20 06:20:10,602][serotiny.ml_ops.mlflow_utils][INFO] - Calling trainer.fit
# [2022-10-20 06:20:13,552][pytorch_lightning.accelerators.gpu][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/model_summary.py:407: UserWarning: A layer with UninitializedParameter was found. Thus, the total number of parameters detected may be inaccurate.
#   warning_cache.warn(
# [2022-10-20 06:20:13,554][pytorch_lightning.callbacks.model_summary][INFO] -
#   | Name    | Type             | Params
# ---------------------------------------------
# 0 | network | Sequential       | 0
# 1 | loss    | CrossEntropyLoss | 0
# ---------------------------------------------
# 0         Trainable params
# 0         Non-trainable params
# 0         Total params
# 0.000     Total estimated model params size (MB)
# Epoch 0:  78%|████████████████▎    | 90/116 [04:44<01:22,  3.16s/it, loss=0.942]
# Epoch 0:  78%|████████████████▎    | 90/116 [05:01<01:27,  3.35s/it, loss=0.942]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 0:  78%|████████████████▍    | 91/116 [05:03<01:23,  3.34s/it, loss=0.942]
# Validation DataLoader 0:   8%|█▍                 | 2/26 [00:05<01:01,  2.55s/it]
# Epoch 0:  79%|████████████████▋    | 92/116 [05:08<01:20,  3.35s/it, loss=0.942]
# Epoch 0:  80%|████████████████▊    | 93/116 [05:08<01:16,  3.32s/it, loss=0.942]
# Epoch 0:  81%|█████████████████    | 94/116 [05:08<01:12,  3.28s/it, loss=0.942]
# Epoch 0:  82%|█████████████████▏   | 95/116 [05:08<01:08,  3.25s/it, loss=0.942]
# Epoch 0:  83%|█████████████████▍   | 96/116 [05:08<01:04,  3.22s/it, loss=0.942]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:14<00:37,  1.99s/it]
# Epoch 0:  84%|█████████████████▌   | 97/116 [05:17<01:02,  3.28s/it, loss=0.942]
# Validation DataLoader 0:  31%|█████▊             | 8/26 [00:19<00:46,  2.57s/it]
# Epoch 0:  84%|█████████████████▋   | 98/116 [05:22<00:59,  3.30s/it, loss=0.942]
# Validation DataLoader 0:  35%|██████▌            | 9/26 [00:19<00:35,  2.11s/it]
# Epoch 0:  85%|█████████████████▉   | 99/116 [05:23<00:55,  3.27s/it, loss=0.942]
# Epoch 0:  86%|█████████████████▏  | 100/116 [05:23<00:51,  3.23s/it, loss=0.942]
# Epoch 0:  87%|█████████████████▍  | 101/116 [05:23<00:48,  3.20s/it, loss=0.942]
# Validation DataLoader 0:  46%|████████▎         | 12/26 [00

# Validation DataLoader 0:  73%|█████████████▏    | 19/26 [00:43<00:19,  2.85s/it]
# Epoch 2:  94%|██████████████████▊ | 109/116 [05:12<00:20,  2.87s/it, loss=0.726]
# Epoch 2:  95%|██████████████████▉ | 110/116 [05:12<00:17,  2.84s/it, loss=0.726]
# Validation DataLoader 0:  81%|██████████████▌   | 21/26 [00:44<00:11,  2.28s/it]
# Epoch 2:  96%|███████████████████▏| 111/116 [05:13<00:14,  2.82s/it, loss=0.726]
# Epoch 2:  97%|███████████████████▎| 112/116 [05:13<00:11,  2.80s/it, loss=0.726]
# Epoch 2:  97%|███████████████████▍| 113/116 [05:13<00:08,  2.77s/it, loss=0.726]
# Epoch 2:  98%|███████████████████▋| 114/116 [05:25<00:05,  2.86s/it, loss=0.726]
# Validation DataLoader 0:  92%|████████████████▌ | 24/26 [00:56<00:04,  2.28s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:56<00:02,  2.59s/it]
# Epoch 2:  99%|███████████████████▊| 115/116 [05:25<00:02,  2.83s/it, loss=0.726]
# Epoch 2: 100%|████████████████████| 116/116 [05:25<00:00,  2.81s/it, loss=0.726]
# Epoch 3:  78%|████████████████▎    | 90/116 [04:05<01:11,  2.73s/it, loss=0.701]
# Epoch 3:  78%|████████████████▎    | 90/116 [04:19<01:15,  2.89s/it, loss=0.701]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 3:  78%|████████████████▍    | 91/116 [04:23<01:12,  2.90s/it, loss=0.701]
# Validation DataLoader 0:   8%|█▍                 | 2/26 [00:03<00:41,  1.74s/it]
# Epoch 3:  79%|████████████████▋    | 92/116 [04:27<01:09,  2.91s/it, loss=0.701]
# Epoch 3:  80%|████████████████▊    | 93/116 [04:27<01:06,  2.87s/it, loss=0.701]
# Epoch 3:  81%|█████████████████    | 94/116 [04:27<01:02,  2.84s/it, loss=0.701]
# Epoch 3:  82%|█████████████████▏   | 95/116 [04:27<00:59,  2.81s/it, loss=0.701]
# Validation DataLoader 0:  23%|████▍              | 6/26 [00:03<00:09,  2.04it/s]
# Epoch 3:  83%|█████████████████▍   | 96/116 [04:27<00:55,  2.79s/it, loss=0.701]
# Epoch 3:  84%|█████████████████▌   | 97/116 [04:39<00:54,  2.88s/it, loss=0.701]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:15<00:09,  2.04it/s]
# Validation DataLoader 0:  31%|█████▊             | 8/26 [00:17<00:48,  2.71s/it]
# Epoch 3:  84%|█████████████████▋   | 98/116 [04:41<00:51,  2.87s/it, loss=0.701]
# Validation DataLoader 0:  35%|██████▌            | 9/26 [00:17<00:38,  2.25s/it]
# Epoch 3:  85%|█████████████████▉   | 99/116 [04:41<00:48,  2.85s/it, loss=0.701]
# Epoch 3:  86%|█████████████████▏  | 100/116 [04:41<00:45,  2.82s/it, loss=0.701]
# Epoch 3:  87%|█████████████████▍  | 101/116 [04:41<00:41,  2.79s/it, loss=0.701]
# Epoch 3:  88%|█████████████████▌  | 102/116 [04:41<00:38,  2.76s/it, loss=0.701]
# Validation DataLoader 0:  50%|█████████         | 13/26 [00:27<00:30,  2.32s/it]
# Epoch 3:  89%|█████████████████▊  | 103/116 [04:51<00:36,  2.83s/it, loss=0.701]
# Validation DataLoader 0:  54%|█████████▋        | 14/26 [00:32<00:32,  2.69s/it]
# Epoch 3:  90%|█████████████████▉  | 104/116 [04:55<00:34,  2.84s/it, loss=0.701]
# Epoch 3:  91%|██████████████████  | 105/116 [04:55<00:30,  2.82s/it, loss=0.701]
# Epoch 3:  91%|██████████████████▎ | 106/116 [04:55<00:27,  2.79s/it, loss=0.701]
# Epoch 3:  92%|██████████████████▍ | 107/116 [04:55<00:24,  2.77s/it, loss=0.701]
# Epoch 3:  93%|██████████████████▌ | 108/116 [04:55<00:21,  2.74s/it, loss=0.701]
# Validation DataLoader 0:  73%|█████████████▏    | 19/26 [00:41<00:15,  2.28s/it]
# Epoch 3:  94%|██████████████████▊ | 109/116 [05:09<00:19,  2.84s/it, loss=0.701]
# Validation DataLoader 0:  77%|█████████████▊    | 20/26 [00:46<00:15,  2.65s/it]
# Epoch 3:  95%|██████████████████▉ | 110/116 [05:10<00:16,  2.82s/it, loss=0.701]
# Epoch 3:  96%|███████████████████▏| 111/116 [05:10<00:13,  2.80s/it, loss=0.701]
# Epoch 3:  97%|███████████████████▎| 112/116 [05:10<00:11,  2.77s/it, loss=0.701]
# Epoch 3:  97%|███████████████████▍| 113/116 [05:10<00:08,  2.75s/it, loss=0.701]
# Epoch 3:  98%|███████████████████▋| 114/116 [05:10<00:05,  2.72s/it, loss=0.701]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:55<00:02,  2.18s/it]
# Epoch 3:  99%|███████████████████▊| 115/116 [05:19<00:02,  2.77s/it, loss=0.701]
# Epoch 3: 100%|████████████████████| 116/116 [05:19<00:00,  2.75s/it, loss=0.701]
# Epoch 4:  78%|████████████████▎    | 90/116 [04:01<01:09,  2.68s/it, loss=0.691]
# Epoch 4:  78%|████████████████▎    | 90/116 [04:20<01:15,  2.89s/it, loss=0.691]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 4:  78%|████████████████▍    | 91/116 [04:22<01:12,  2.89s/it, loss=0.691]
# Epoch 4:  79%|████████████████▋    | 92/116 [04:22<01:08,  2.85s/it, loss=0.691]
# Epoch 4:  80%|████████████████▊    | 93/116 [04:22<01:04,  2.82s/it, loss=0.691]
# Validation DataLoader 0:  15%|██▉                | 4/26 [00:01<00:09,  2.39it/s]
# Epoch 4:  81%|█████████████████    | 94/116 [04:24<01:01,  2.81s/it, loss=0.691]
# Epoch 4:  82%|█████████████████▏   | 95/116 [04:24<00:58,  2.78s/it, loss=0.691]
# Epoch 4:  83%|█████████████████▍   | 96/116 [04:24<00:55,  2.75s/it, loss=0.691]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:15<00:48,  2.56s/it]
# Epoch 4:  84%|█████████████████▌   | 97/116 [04:37<00:54,  2.87s/it, loss=0.691]
# Epoch 4:  84%|█████████████████▋   | 98/116 [04:37<00:51,  2.84s/it, loss=0.691]
# Epoch 4:  85%|█████████████████▉   | 99/116 [04:38<00:47,  2.81s/it, loss=0.691]
# Validation DataLoader 0:  38%|██████▉           | 10/26 [00:15<00:24,  1.51s/it]
# Epoch 4:  86%|█████████████████▏  | 100/116 [04:38<00:44,  2.78s/it, loss=0.691]
# Epoch 4:  87%|█████████████████▍  | 101/116 [04:38<00:41,  2.75s/it, loss=0.691]
# Epoch 4:  88%|█████████████████▌  | 102/116 [04:50<00:39,  2.85s/it, loss=0.691]
# Validation DataLoader 0:  50%|█████████         | 13/26 [00:29<00:35,  2.74s/it]
# Epoch 4:  89%|█████████████████▊  | 103/116 [04:52<00:36,  2.84s/it, loss=0.691]
# Epoch 4:  90%|█████████████████▉  | 104/116 [04:52<00:33,  2.81s/it, loss=0.691]
# Epoch 4:  91%|██████████████████  | 105/116 [04:52<00:30,  2.79s/it, loss=0.691]
# Epoch 4:  91%|██████████████████▎ | 106/116 [04:52<00:27,  2.76s/it, loss=0.691]
# Epoch 4:  92%|██████████████████▍ | 107/116 [04:52<00:24,  2.73s/it, loss=0.691]
# Validation DataLoader 0:  69%|████████████▍     | 18/26 [00:30<00:11,  1.46s/it]
# Epoch 4:  93%|██████████████████▌ | 108/116 [04:52<00:21,  2.71s/it, loss=0.691]
# Epoch 4:  94%|██████████████████▊ | 109/116 [05:06<00:19,  2.81s/it, loss=0.691]
# Validation DataLoader 0:  77%|█████████████▊    | 20/26 [00:43<00:15,  2.61s/it]
# Epoch 4:  95%|██████████████████▉ | 110/116 [05:06<00:16,  2.79s/it, loss=0.691]
# Epoch 4:  96%|███████████████████▏| 111/116 [05:06<00:13,  2.76s/it, loss=0.691]
# Validation DataLoader 0:  85%|███████████████▏  | 22/26 [00:44<00:08,  2.10s/it]
# Epoch 4:  97%|███████████████████▎| 112/116 [05:07<00:10,  2.74s/it, loss=0.691]
# Epoch 4:  97%|███████████████████▍| 113/116 [05:07<00:08,  2.72s/it, loss=0.691]
# Epoch 4:  98%|███████████████████▋| 114/116 [05:07<00:05,  2.70s/it, loss=0.691]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:56<00:02,  2.68s/it]
# Epoch 4:  99%|███████████████████▊| 115/116 [05:18<00:02,  2.77s/it, loss=0.691]
# Epoch 4: 100%|████████████████████| 116/116 [05:18<00:00,  2.75s/it, loss=0.691]
# Epoch 5:  78%|████████████████▎    | 90/116 [03:58<01:08,  2.65s/it, loss=0.645]
# Epoch 5:  78%|████████████████▎    | 90/116 [04:11<01:12,  2.80s/it, loss=0.645]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 5:  78%|████████████████▍    | 91/116 [04:20<01:11,  2.86s/it, loss=0.645]
# Epoch 5:  79%|████████████████▋    | 92/116 [04:20<01:07,  2.83s/it, loss=0.645]
# Epoch 5:  80%|████████████████▊    | 93/116 [04:20<01:04,  2.80s/it, loss=0.645]
# Epoch 5:  81%|█████████████████    | 94/116 [04:20<01:00,  2.77s/it, loss=0.645]
# Epoch 5:  82%|█████████████████▏   | 95/116 [04:20<00:57,  2.74s/it, loss=0.645]
# Validation DataLoader 0:  23%|████▍              | 6/26 [00:00<00:00, 49.25it/s]
# Epoch 5:  83%|█████████████████▍   | 96/116 [04:31<00:56,  2.83s/it, loss=0.645]
# Validation DataLoader 0:  23%|████▍              | 6/26 [00:11<00:00, 49.25it/s]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:15<00:58,  3.06s/it]
# Epoch 5:  84%|█████████████████▌   | 97/116 [04:36<00:54,  2.85s/it, loss=0.645]
# Epoch 5:  84%|█████████████████▋   | 98/116 [04:36<00:50,  2.82s/it, loss=0.645]
# Epoch 5:  85%|█████████████████▉   | 99/116 [04:36<00:47,  2.79s/it, loss=0.645]
# Epoch 5:  86%|█████████████████▏  | 100/116 [04:36<00:44,  2.76s/it, loss=0.645]
# Epoch 5:  87%|█████████████████▍  | 101/116 [04:36<00:41,  2.74s/it, loss=0.645]
# Validation DataLoader 0:  46%|████████▎         | 12/26 [00:16<00:18,  1.30s/it]
# Epoch 5:  88%|█████████████████▌  | 102/116 [04:36<00:37,  2.71s/it, loss=0.645]
# Epoch 5:  89%|█████████████████▊  | 103/116 [04:50<00:36,  2.82s/it, loss=0.645]
# Epoch 5:  90%|█████████████████▉  | 104/116 [04:50<00:33,  2.79s/it, loss=0.645]
# Epoch 5:  91%|██████████████████  | 105/116 [04:50<00:30,  2.76s/it, loss=0.645]
# Epoch 5:  91%|██████████████████▎ | 106/116 [04:50<00:27,  2.74s/it, loss=0.645]
# Validation DataLoader 0:  65%|███████████▊      | 17/26 [00:29<00:17,  1.97s/it]
# Epoch 5:  92%|██████████████████▍ | 107/116 [04:50<00:24,  2.71s/it, loss=0.645]
# Epoch 5:  93%|██████████████████▌ | 108/116 [04:50<00:21,  2.69s/it, loss=0.645]
# Validation DataLoader 0:  73%|█████████████▏    | 19/26 [00:43<00:20,  2.95s/it]
# Epoch 5:  94%|██████████████████▊ | 109/116 [05:03<00:19,  2.79s/it, loss=0.645]
# Epoch 5:  95%|██████████████████▉ | 110/116 [05:03<00:16,  2.76s/it, loss=0.645]
# Validation DataLoader 0:  81%|██████████████▌   | 21/26 [00:44<00:11,  2.35s/it]
# Epoch 5:  96%|███████████████████▏| 111/116 [05:04<00:13,  2.74s/it, loss=0.645]
# Epoch 5:  97%|███████████████████▎| 112/116 [05:04<00:10,  2.72s/it, loss=0.645]
# Epoch 5:  97%|███████████████████▍| 113/116 [05:04<00:08,  2.69s/it, loss=0.645]
# Epoch 5:  98%|███████████████████▋| 114/116 [05:04<00:05,  2.67s/it, loss=0.645]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:55<00:02,  2.59s/it]
# Epoch 5:  99%|███████████████████▊| 115/116 [05:16<00:02,  2.75s/it, loss=0.645]
# Epoch 5: 100%|████████████████████| 116/116 [05:16<00:00,  2.73s/it, loss=0.645]
# Epoch 6:  78%|████████████████▎    | 90/116 [04:02<01:09,  2.69s/it, loss=0.604]
# Epoch 6:  78%|████████████████▎    | 90/116 [04:15<01:13,  2.83s/it, loss=0.604]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 6:  78%|████████████████▍    | 91/116 [04:23<01:12,  2.89s/it, loss=0.604]
# Epoch 6:  79%|████████████████▋    | 92/116 [04:23<01:08,  2.86s/it, loss=0.604]
# Epoch 6:  80%|████████████████▊    | 93/116 [04:23<01:05,  2.83s/it, loss=0.604]
# Epoch 6:  81%|█████████████████    | 94/116 [04:23<01:01,  2.80s/it, loss=0.604]
# Epoch 6:  82%|█████████████████▏   | 95/116 [04:23<00:58,  2.77s/it, loss=0.604]
# Validation DataLoader 0:  23%|████▍              | 6/26 [00:00<00:00, 52.93it/s]
# Epoch 6:  83%|█████████████████▍   | 96/116 [04:35<00:57,  2.87s/it, loss=0.604]
# Validation DataLoader 0:  23%|████▍              | 6/26 [00:11<00:00, 52.93it/s]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:15<00:55,  2.93s/it]
# Epoch 6:  84%|█████████████████▌   | 97/116 [04:38<00:54,  2.87s/it, loss=0.604]
# Epoch 6:  84%|█████████████████▋   | 98/116 [04:38<00:51,  2.84s/it, loss=0.604]
# Epoch 6:  85%|█████████████████▉   | 99/116 [04:38<00:47,  2.81s/it, loss=0.604]
# Epoch 6:  86%|█████████████████▏  | 100/116 [04:38<00:44,  2.79s/it, loss=0.604]
# Epoch 6:  87%|█████████████████▍  | 101/116 [04:38<00:41,  2.76s/it, loss=0.604]
# Validation DataLoader 0:  46%|████████▎         | 12/26 [00:15<00:17,  1.25s/it]
# Epoch 6:  88%|█████████████████▌  | 102/116 [04:38<00:38,  2.73s/it, loss=0.604]
# Epoch 6:  89%|█████████████████▊  | 103/116 [04:52<00:36,  2.84s/it, loss=0.604]
# Epoch 6:  90%|█████████████████▉  | 104/116 [04:52<00:33,  2.81s/it, loss=0.604]
# Epoch 6:  91%|██████████████████  | 105/116 [04:52<00:30,  2.79s/it, loss=0.604]
# Epoch 6:  91%|██████████████████▎ | 106/116 [04:52<00:27,  2.76s/it, loss=0.604]
# Validation DataLoader 0:  65%|███████████▊      | 17/26 [00:29<00:17,  1.96s/it]
# Epoch 6:  92%|██████████████████▍ | 107/116 [04:52<00:24,  2.74s/it, loss=0.604]
# Epoch 6:  93%|██████████████████▌ | 108/116 [04:52<00:21,  2.71s/it, loss=0.604]
# Validation DataLoader 0:  73%|█████████████▏    | 19/26 [00:43<00:21,  3.03s/it]
# Epoch 6:  94%|██████████████████▊ | 109/116 [05:07<00:19,  2.82s/it, loss=0.604]
# Epoch 6:  95%|██████████████████▉ | 110/116 [05:07<00:16,  2.79s/it, loss=0.604]
# Epoch 6:  96%|███████████████████▏| 111/116 [05:07<00:13,  2.77s/it, loss=0.604]
# Epoch 6:  97%|███████████████████▎| 112/116 [05:07<00:10,  2.74s/it, loss=0.604]
# Epoch 6:  97%|███████████████████▍| 113/116 [05:07<00:08,  2.72s/it, loss=0.604]
# Epoch 6:  98%|███████████████████▋| 114/116 [05:07<00:05,  2.70s/it, loss=0.604]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:56<00:02,  2.62s/it]
# Epoch 6:  99%|███████████████████▊| 115/116 [05:20<00:02,  2.78s/it, loss=0.604]
# Epoch 6: 100%|████████████████████| 116/116 [05:20<00:00,  2.76s/it, loss=0.604]
# Epoch 7:  78%|████████████████▎    | 90/116 [04:17<01:14,  2.86s/it, loss=0.623]
# Epoch 7:  78%|████████████████▎    | 90/116 [04:34<01:19,  3.05s/it, loss=0.623]
# Validation:   0%|                                        | 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/26 [00:00<?, ?it/s]
# Epoch 7:  78%|████████████████▍    | 91/116 [04:38<01:16,  3.06s/it, loss=0.623]
# Validation DataLoader 0:   8%|█▍                 | 2/26 [00:00<00:01, 17.07it/s]
# Epoch 7:  79%|████████████████▋    | 92/116 [04:38<01:12,  3.03s/it, loss=0.623]
# Epoch 7:  80%|████████████████▊    | 93/116 [04:39<01:09,  3.01s/it, loss=0.623]
# Validation DataLoader 0:  15%|██▉                | 4/26 [00:01<00:10,  2.08it/s]
# Epoch 7:  81%|█████████████████    | 94/116 [04:40<01:05,  2.98s/it, loss=0.623]
# Epoch 7:  82%|█████████████████▏   | 95/116 [04:40<01:01,  2.95s/it, loss=0.623]
# Epoch 7:  83%|█████████████████▍   | 96/116 [04:40<00:58,  2.92s/it, loss=0.623]
# Validation DataLoader 0:  27%|█████              | 7/26 [00:16<00:55,  2.90s/it]
# Epoch 7:  84%|█████████████████▌   | 97/116 [04:54<00:57,  3.04s/it, loss=0.623]
# Epoch 7:  84%|█████████████████▋   | 98/116 [04:54<00:54,  3.01s/it, loss=0.623]
# Epoch 7:  85%|█████████████████▉   | 99/116 [04:54<00:50,  2.98s/it, loss=0.623]
# Validation DataLoader 0:  38%|██████▉           | 10/26 [00:16<00:26,  1.64s/it]
# Epoch 7:  86%|█████████████████▏  | 100/116 [04:54<00:47,  2.95s/it, loss=0.623]
# Epoch 7:  87%|█████████████████▍  | 101/116 [04:54<00:43,  2.92s/it, loss=0.623]
# Epoch 7:  88%|█████████████████▌  | 102/116 [05:04<00:41,  2.99s/it, loss=0.623]
# Validation DataLoader 0:  46%|████████▎         | 12/26 [00:26<00:22,  1.64s/it]
# Validation DataLoader 0:  50%|█████████         | 13/26 [00:30<00:37,  2.90s/it]
# Epoch 7:  89%|█████████████████▊  | 103/116 [05:09<00:39,  3.00s/it, loss=0.623]
# Epoch 7:  90%|█████████████████▉  | 104/116 [05:09<00:35,  2.98s/it, loss=0.623]
# Epoch 7:  91%|██████████████████  | 105/116 [05:09<00:32,  2.95s/it, loss=0.623]
# Validation DataLoader 0:  62%|███████████       | 16/26 [00:31<00:19,  1.93s/it]
# Epoch 7:  91%|██████████████████▎ | 106/116 [05:09<00:29,  2.92s/it, loss=0.623]
# Epoch 7:  92%|██████████████████▍ | 107/116 [05:09<00:26,  2.90s/it, loss=0.623]
# Validation DataLoader 0:  69%|████████████▍     | 18/26 [00:32<00:12,  1.52s/it]
# Epoch 7:  93%|██████████████████▌ | 108/116 [05:10<00:23,  2.88s/it, loss=0.623]
# Validation DataLoader 0:  73%|█████████████▏    | 19/26 [00:45<00:23,  3.37s/it]
# Epoch 7:  94%|██████████████████▊ | 109/116 [05:24<00:20,  2.97s/it, loss=0.623]
# Epoch 7:  95%|██████████████████▉ | 110/116 [05:24<00:17,  2.95s/it, loss=0.623]
# Validation DataLoader 0:  81%|██████████████▌   | 21/26 [00:46<00:12,  2.43s/it]
# Epoch 7:  96%|███████████████████▏| 111/116 [05:24<00:14,  2.93s/it, loss=0.623]
# Validation DataLoader 0:  85%|███████████████▏  | 22/26 [00:47<00:08,  2.20s/it]
# Epoch 7:  97%|███████████████████▎| 112/116 [05:25<00:11,  2.91s/it, loss=0.623]
# Epoch 7:  97%|███████████████████▍| 113/116 [05:25<00:08,  2.88s/it, loss=0.623]
# Epoch 7:  98%|███████████████████▋| 114/116 [05:25<00:05,  2.86s/it, loss=0.623]
# Validation DataLoader 0:  96%|█████████████████▎| 25/26 [00:59<00:02,  2.97s/it]
# Epoch 7:  99%|███████████████████▊| 115/116 [05:37<00:02,  2.94s/it, loss=0.623]
# Epoch 7: 100%|████████████████████| 116/116 [05:37<00:00,  2.91s/it, loss=0.623]
# Epoch 7: 100%|████████████████████| 116/116 [05:37<00:00,  2.91s/it, loss=0.623]
# 2022/10/20 07:04:47 WARNING mlflow.utils.requirements_utils: Found torch version (1.12.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torch==1.12.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 07:04:55 WARNING mlflow.utils.requirements_utils: Found torchvision version (0.13.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torchvision==0.13.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 07:04:55 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
import mlflow
from serotiny.ml_ops.mlflow_utils import download_artifact

# %%
print(run_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 print(run_name)
#
# NameError: name 'run_name' is not defined

# %%
run_name = 'keith_bf_noDropout_20221020_062002'

# %%
# !serotiny predict \
    model=brightfield_classifier_3d_noDropOut \
    data=brightfield_dataloader_3d \
    mlflow.experiment_name=eyeballExpress \
    mlflow.run_name={run_name} \
    trainer.gpus=[0]
# Out:
# [2022-10-20 16:43:11,611][pytorch_lightning.utilities.seed][INFO] - Global seed set to 42
# [2022-10-20 16:43:11,612][serotiny.ml_ops.ml_ops][INFO] - Instantiating datamodule
# [2022-10-20 16:43:14,072][serotiny.ml_ops.ml_ops][INFO] - Instantiating trainer
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py:91: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# [2022-10-20 16:43:14,125][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True, used: True
# [2022-10-20 16:43:14,126][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2022-10-20 16:43:14,126][pytorch_lightning.utilities.rank_zero][INFO] - IPU available: False, using: 0 IPUs
# [2022-10-20 16:43:14,126][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2022-10-20 16:43:14,126][serotiny.ml_ops.ml_ops][INFO] - Instantiating model
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# [2022-10-20 16:43:14,169][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmpzzgx4bsc
# [2022-10-20 16:43:14,169][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmpzzgx4bsc/_remote_module_non_scriptable.py
# [2022-10-20 16:43:14,184][serotiny.ml_ops.mlflow_utils][INFO] - Validating and processing MLFlow configuration
# /opt/conda/lib/python3.10/site-packages/serotiny/ml_ops/mlflow_utils.py:156: FutureWarning: ``mlflow.tracking.fluent.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   for run_info in mlflow.list_run_infos(experiment_id=experiment_id):
# /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1599: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   return MlflowClient().list_run_infos(
# [2022-10-20 16:43:15,102][serotiny.ml_ops.mlflow_utils][INFO] - Calling trainer.predict
# [2022-10-20 16:43:17,624][pytorch_lightning.accelerators.gpu][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|████████████████| 128/128 [06:10<00:00,  2.89s/it]
# 2022/10/20 16:49:49 WARNING mlflow.utils.requirements_utils: Found torch version (1.12.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torch==1.12.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 16:49:57 WARNING mlflow.utils.requirements_utils: Found torchvision version (0.13.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torchvision==0.13.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 16:49:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
# don't run
# !serotiny predict \
#     model=brightfield_classifier_3d \
#     data=brightfield_dataloader_3d \
#     mlflow.experiment_name=cytodata_chapter5 \
#     mlflow.run_name={"keith_bf_test6_20221020_013836"} \
#     trainer.gpus=[0]
# Out:
# [2022-10-20 05:35:15,108][pytorch_lightning.utilities.seed][INFO] - Global seed set to 42
# [2022-10-20 05:35:15,109][serotiny.ml_ops.ml_ops][INFO] - Instantiating datamodule
# [2022-10-20 05:35:17,562][serotiny.ml_ops.ml_ops][INFO] - Instantiating trainer
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py:91: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# [2022-10-20 05:35:17,619][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True, used: True
# [2022-10-20 05:35:17,619][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2022-10-20 05:35:17,619][pytorch_lightning.utilities.rank_zero][INFO] - IPU available: False, using: 0 IPUs
# [2022-10-20 05:35:17,619][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2022-10-20 05:35:17,619][serotiny.ml_ops.ml_ops][INFO] - Instantiating model
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# [2022-10-20 05:35:17,664][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmpacr1bpmu
# [2022-10-20 05:35:17,664][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmpacr1bpmu/_remote_module_non_scriptable.py
# [2022-10-20 05:35:17,679][serotiny.ml_ops.mlflow_utils][INFO] - Validating and processing MLFlow configuration
# /opt/conda/lib/python3.10/site-packages/serotiny/ml_ops/mlflow_utils.py:156: FutureWarning: ``mlflow.tracking.fluent.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   for run_info in mlflow.list_run_infos(experiment_id=experiment_id):
# /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1599: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   return MlflowClient().list_run_infos(
# [2022-10-20 05:35:22,374][serotiny.ml_ops.mlflow_utils][INFO] - Calling trainer.predict
# [2022-10-20 05:35:24,866][pytorch_lightning.accelerators.gpu][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|████████████████| 128/128 [05:54<00:00,  2.77s/it]
# 2022/10/20 05:41:41 WARNING mlflow.utils.requirements_utils: Found torch version (1.12.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torch==1.12.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 05:41:49 WARNING mlflow.utils.requirements_utils: Found torchvision version (0.13.1+cu113) contains a local version label (+cu113). MLflow logged a pip requirement for this package as 'torchvision==0.13.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2022/10/20 05:41:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
mlflow.set_tracking_uri("http://mlflow.mlflow.svc.cluster.local")

#with download_artifact("predictions/model_predictions_multiclass.csv", experiment_name="eyeballExpress", run_name=run_name) as path:
#    predictions_3d_df = pd.read_csv(path)

with download_artifact("predictions/model_predictions_multiclass.csv", experiment_name="eyeballExpress", run_name=run_name) as path:
    predictions_3d_df = pd.read_csv(path)
# Out:
# /opt/conda/lib/python3.10/site-packages/serotiny/ml_ops/mlflow_utils.py:144: FutureWarning: ``mlflow.tracking.fluent.list_experiments`` is deprecated. This method will be removed in a future release. Use ``search_experiments()`` instead.
#   for _experiment in mlflow.list_experiments():
# /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1066: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_experiments`` is deprecated. This method will be removed in a future release. Use ``search_experiments()`` instead.
#   return MlflowClient().list_experiments(
# /opt/conda/lib/python3.10/site-packages/serotiny/ml_ops/mlflow_utils.py:156: FutureWarning: ``mlflow.tracking.fluent.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   for run_info in mlflow.list_run_infos(experiment_id=experiment_id):
# /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1599: FutureWarning: ``mlflow.tracking.client.MlflowClient.list_run_infos`` is deprecated. This method will be removed in a future release. Use ``search_runs()`` instead.
#   return MlflowClient().list_run_infos(

# %%
df_mitocells = pd.read_csv("/home/aicsuser/serotiny_data/keith_mitocells.csv")
predictions_3d_df = predictions_3d_df.merge(df_mitocells[['CellId','split']].rename(columns={'CellId':'id'}), on = 'id')
predictions_3d_df.head()
# Out:
#        id  y  yhat      loss  split
# 0  401548  0     0  0.139929  valid
# 1  707844  0     0  0.139929  valid
# 2  801697  0     0  0.139929  train
# 3  313392  0     0  0.139929  train
# 4  393229  0     0  0.139929  train

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# make confusion matrix for each split
splits = ['train','valid','test']
fig, axes = plt.subplots(nrows=1,ncols=len(splits),figsize=(10, 3), dpi=100)

for i,split in enumerate(splits):
    
    y_true = predictions_3d_df[predictions_3d_df['split']==split]['y'].to_numpy()
    y_pred = predictions_3d_df[predictions_3d_df['split']==split]['yhat'].to_numpy()
    y_pred = np.round(y_pred) #get to crisp binary class labels from posterior probability

    # Computer confusion matrix
    cm = confusion_matrix(y_true, y_pred)    
    score = accuracy_score(y_true,y_pred) #compute accuracy score
    cm_df = pd.DataFrame(cm)
    sns.heatmap(cm_df, annot=True, fmt='d',ax = axes[i])
    axes[i].set_title(f'Accuracy on {split} is {score:.2f}')
    axes[i].set_xlabel('True')
    axes[i].set_ylabel('Predicted')

plt.show()
# plt.savefig('cytodata_hackathon_2022_BF_3d.png')

# %%
pwd
# Out:
# '/home/aicsuser/eyeballExpress/cytodata-hackathon-base'
